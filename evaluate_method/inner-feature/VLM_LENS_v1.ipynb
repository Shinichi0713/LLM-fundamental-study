# %% [markdown]
# https://lifetechia.com/vlm-lens-vision-language-model-analysis/

# %%
# !git clone https://github.com/compling-wat/vlm-lens.git
# %cd vlm-lens
# Out:
# fatal: destination path 'vlm-lens' already exists and is not an empty directory.
# /content/vlm-lens

# %%
# !pip install virtualenv
# !pip install PyYAML
# Out:
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.12/dist-packages (20.29.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv) (0.3.9)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv) (3.17.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv) (4.3.6)

# %%
# !virtualenv --no-download "venv/vlm-lens-base" --prompt "vlm-lens-base"  # Or "python3.10 -m venv venv/vlm-lens-base"
# !source venv/vlm-lens-base/bin/activate
# Out:
# created virtual environment CPython3.12.12.final.0-64 in 405ms
#   creator CPython3Posix(dest=/content/vlm-lens/venv/vlm-lens-base, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==24.3.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !pip install --upgrade pip
# !pip install -r envs/base/requirements.txt
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (25.2)
# Requirement already satisfied: certifi==2024.12.14 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 1)) (2024.12.14)
# Requirement already satisfied: cfgv==3.4.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: charset-normalizer==3.4.1 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: datasets==3.6.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: distlib==0.3.9 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 5)) (0.3.9)
# Requirement already satisfied: filelock==3.17.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 6)) (3.17.0)
# Requirement already satisfied: fsspec==2024.12.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 7)) (2024.12.0)
# Requirement already satisfied: huggingface-hub==0.30.2 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 8)) (0.30.2)
# Requirement already satisfied: identify==2.6.6 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 9)) (2.6.6)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 10)) (3.10)
# Requirement already satisfied: Jinja2==3.1.5 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 11)) (3.1.5)
# Requirement already satisfied: MarkupSafe==3.0.2 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 12)) (3.0.2)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: networkx==3.4.2 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 14)) (3.4.2)
# Requirement already satisfied: nodeenv==1.9.1 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 15)) (1.9.1)
# Requirement already satisfied: numpy==2.1.1 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 16)) (2.1.1)
# Requirement already satisfied: packaging==24.2 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 17)) (24.2)
# Requirement already satisfied: pillow==11.1.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 18)) (11.1.0)
# Requirement already satisfied: platformdirs==4.3.6 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 19)) (4.3.6)
# Requirement already satisfied: pre_commit==4.1.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 20)) (4.1.0)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 21)) (6.0.2)
# Requirement already satisfied: regex==2024.11.6 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 22)) (2024.11.6)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 23)) (2.32.3)
# Requirement already satisfied: safetensors==0.5.3 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 24)) (0.5.3)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 25)) (1.13.1)
# Requirement already satisfied: tokenizers==0.21.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 26)) (0.21.0)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 27)) (2.6.0)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 28)) (4.67.1)
# Requirement already satisfied: transformers==4.51.3 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 29)) (4.51.3)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 30)) (3.2.0)
# Requirement already satisfied: typing_extensions==4.12.2 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 31)) (4.12.2)
# Requirement already satisfied: urllib3==2.3.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 32)) (2.3.0)
# Requirement already satisfied: virtualenv==20.29.1 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 33)) (20.29.1)
# Requirement already satisfied: wget==3.2 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 34)) (3.2)
# Requirement already satisfied: accelerate==1.10.1 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 35)) (1.10.1)
# Requirement already satisfied: sentencepiece==0.2.0 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 36)) (0.2.0)
# Requirement already satisfied: protobuf==6.32.1 in /usr/local/lib/python3.12/dist-packages (from -r envs/base/requirements.txt (line 37)) (6.32.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (0.70.16)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (12.4.127)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.6.0->-r envs/base/requirements.txt (line 27)) (75.2.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==1.10.1->-r envs/base/requirements.txt (line 35)) (5.9.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (3.13.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (1.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.6.0->-r envs/base/requirements.txt (line 4)) (1.17.0)

# %% [markdown]
# vml-lensは制御をyamlファイルで制御している。
#
# ### yamlの内容
# architecture: 使用するVLMのアーキテクチャを指定します (例: blip2, clip, llava)。
# model_path: モデルのパスを指定します。Hugging Face Hubからモデルをダウンロードする場合は、リポジトリ名を指定します。
# model: モデルのロードに関する設定を行います。torch_dtype: autoは、自動的に適切なデータ型を選択することを意味します。
# output_db: 抽出されたデータを保存するSQLite3データベースのパスを指定します。
# input_dir: 入力画像が格納されているディレクトリを指定します。
# prompt: VLMに入力するテキストプロンプトを指定します。
# modules: 抽出するVLMのモジュール（レイヤー）を指定します。--log-named-modulesオプションを使用すると、モデルのレイヤー構造を確認できます。

# %%
import yaml

# YAMLに書き出す内容をPythonの辞書で表現
data = {
    'architecture': 'blip2',
    'model_path': 'Salesforce/blip2-opt-2.7b',
    'model': {
        'torch_dtype': 'auto'
    },
    'output_db': 'output/blip2.db',
    'input_dir': './data/test-images/',
    'prompt': 'Describe the color in this image in one word.',
    'modules': [
        'language_model.lm_head',
        'vision_model.post_layernorm'
    ]
}

# ファイル名
filename = 'config_blip.yaml'

# ファイルに書き出す
with open(filename, 'w') as file:
    yaml.dump(data, file, sort_keys=False) # sort_keys=Falseで元の順序を維持

print(f"'{filename}'が作成されました。")

# 作成されたファイルの内容を確認
with open(filename, 'r') as file:
    print("\n--- ファイル内容 ---")
    print(file.read())
# Out:
# 'config_blip.yaml'が作成されました。
#
# --- ファイル内容 ---
# architecture: blip2
# model_path: Salesforce/blip2-opt-2.7b
# model:
#   torch_dtype: auto
# output_db: output/blip2.db
# input_dir: /data/test-images/
# prompt: Describe the color in this image in one word.
# modules:
# - language_model.lm_head
# - vision_model.post_layernorm

# %% [markdown]
# https://pytorch.org/get-started/previous-versions/
#
# もし、pytorch、torchvisionのバージョンがあってない場合、上記サイトを確認してインストールしなおす必要がある。
#
# インストールすべきバージョンは使っているcudaをもとに選択する。
#
# cudaのバージョンは以下で確認する。

# %%
# !nvidia-smi
# Out:
# Sat Oct 18 22:47:55 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip uninstall -y torch torchvision
# !pip install torch==2.8.0 torchvision==0.23.0 torchaudio==2.8.0
# Out:
# Found existing installation: torch 2.6.0
# Uninstalling torch-2.6.0:
#   Successfully uninstalled torch-2.6.0
# Found existing installation: torchvision 0.23.0+cu126
# Uninstalling torchvision-0.23.0+cu126:
#   Successfully uninstalled torchvision-0.23.0+cu126

# %% [markdown]
# コマンド実行。
#
# 実行結果はyamlに指定したデータベースに格納される。

# %%
# !python -m src.main --config /content/vlm-lens/configs/models/blip2/blip2-opt-2.7b.yaml
# Out:
# 2025-10-18 22:55:24.526062: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760828124.546935    9558 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760828124.553763    9558 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760828124.571192    9558 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760828124.571220    9558 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760828124.571224    9558 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760828124.571229    9558 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-18 22:55:24.575796: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# config.json: 1.03kB [00:00, 4.24MB/s]
# model.safetensors.index.json: 122kB [00:00, 202MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0% 0.00/10.0G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0% 570k/4.98G [00:02<6:11:38, 223kB/s]
#
# model-00001-of-00002.safetensors:   0% 2.10M/10.0G [00:02<3:40:31, 755kB/s]
#
# model-00001-of-00002.safetensors:   0% 16.5M/10.0G [00:03<26:18, 6.32MB/s]
#
# model-00001-of-00002.safetensors:   1% 54.3M/10.0G [00:05<12:59, 12.8MB/s]
#
# model-00001-of-00002.safetensors:   1% 114M/10.0G [00:07<07:53, 20.9MB/s]
#
# model-00001-of-00002.safetensors:   2% 187M/10.0G [00:08<05:01, 32.5MB/s]
# model-00002-of-00002.safetensors:   0% 1.98M/4.98G [00:09<6:20:32, 218kB/s]
#
# model-00001-of-00002.safetensors:   2% 237M/10.0G [00:10<05:24, 30.1MB/s]
#
# model-00001-of-00002.safetensors:   4% 363M/10.0G [00:13<04:26, 36.1MB/s]
# model-00002-of-00002.safetensors:   1% 69.1M/4.98G [00:13<12:40, 6.46MB/s]
#
# model-00001-of-00002.safetensors:   4% 430M/10.0G [00:14<03:57, 40.3MB/s]
# model-00002-of-00002.safetensors:   3% 136M/4.98G [00:14<05:57, 13.6MB/s]
#
# model-00001-of-00002.safetensors:   5% 498M/10.0G [00:15<03:47, 41.7MB/s]
# model-00002-of-00002.safetensors:   5% 270M/4.98G [00:16<02:39, 29.6MB/s]
#
# model-00001-of-00002.safetensors:   6% 567M/10.0G [00:16<02:52, 54.6MB/s]
# model-00002-of-00002.safetensors:   7% 337M/4.98G [00:17<02:05, 36.9MB/s]
# model-00002-of-00002.safetensors:   8% 404M/4.98G [00:18<01:49, 41.9MB/s]
#
# model-00001-of-00002.safetensors:   6% 634M/10.0G [00:18<03:28, 44.9MB/s]
#
# model-00001-of-00002.safetensors:   6% 644M/10.0G [00:19<03:53, 40.0MB/s]
# model-00002-of-00002.safetensors:  11% 539M/4.98G [00:19<01:18, 56.8MB/s]
#
# model-00001-of-00002.safetensors:   7% 712M/10.0G [00:20<03:27, 44.7MB/s]
#
# model-00001-of-00002.safetensors:   8% 779M/10.0G [00:22<04:21, 35.3MB/s]
# model-00002-of-00002.safetensors:  14% 673M/4.98G [00:23<01:31, 47.2MB/s]
#
# model-00001-of-00002.safetensors:   9% 894M/10.0G [00:26<04:46, 31.8MB/s]
# model-00002-of-00002.safetensors:  15% 740M/4.98G [00:27<02:06, 33.6MB/s]
# model-00002-of-00002.safetensors:  16% 807M/4.98G [00:28<01:52, 37.1MB/s]
#
# model-00001-of-00002.safetensors:  10% 961M/10.0G [00:33<07:14, 20.8MB/s]
# model-00002-of-00002.safetensors:  19% 941M/4.98G [00:33<02:06, 31.9MB/s]
# model-00002-of-00002.safetensors:  20% 1.01G/4.98G [00:34<01:47, 37.0MB/s]
#
# model-00001-of-00002.safetensors:  10% 1.03G/10.0G [00:34<05:48, 25.7MB/s]
#
# model-00001-of-00002.safetensors:  11% 1.10G/10.0G [00:35<04:53, 30.3MB/s]
# model-00002-of-00002.safetensors:  22% 1.08G/4.98G [00:36<01:58, 33.0MB/s]
#
# model-00001-of-00002.safetensors:  12% 1
B/s]
#
# model-00001-of-00002.safetensors:  74% 7.36G/10.0G [05:28<03:19, 13.2MB/s]
#
# model-00001-of-00002.safetensors:  74% 7.43G/10.0G [05:28<02:24, 17.8MB/s]
#
# model-00001-of-00002.safetensors:  75% 7.50G/10.0G [05:29<01:49, 22.8MB/s]
#
# model-00001-of-00002.safetensors:  76% 7.56G/10.0G [05:29<01:21, 29.7MB/s]
#
# model-00001-of-00002.safetensors:  76% 7.63G/10.0G [05:30<00:59, 39.8MB/s]
#
# model-00001-of-00002.safetensors:  77% 7.70G/10.0G [05:36<01:46, 21.6MB/s]
#
# model-00001-of-00002.safetensors:  77% 7.70G/10.0G [05:48<01:46, 21.6MB/s]
#
# model-00001-of-00002.safetensors:  78% 7.76G/10.0G [05:59<04:55, 7.56MB/s]
#
# model-00001-of-00002.safetensors:  78% 7.83G/10.0G [05:59<03:27, 10.4MB/s]
#
# model-00001-of-00002.safetensors:  79% 7.90G/10.0G [06:00<02:24, 14.5MB/s]
#
# model-00001-of-00002.safetensors:  80% 7.98G/10.0G [06:01<01:35, 21.0MB/s]
#
# model-00001-of-00002.safetensors:  81% 8.05G/10.0G [06:01<01:09, 28.0MB/s]
#
# model-00001-of-00002.safetensors:  81% 8.12G/10.0G [06:07<01:33, 20.0MB/s]
#
# model-00001-of-00002.safetensors:  82% 8.19G/10.0G [06:12<01:46, 17.0MB/s]
#
# model-00001-of-00002.safetensors:  83% 8.25G/10.0G [06:13<01:16, 22.9MB/s]
#
# model-00001-of-00002.safetensors:  83% 8.32G/10.0G [06:13<00:56, 29.7MB/s]
#
# model-00001-of-00002.safetensors:  84% 8.39G/10.0G [06:14<00:42, 37.9MB/s]
#
# model-00001-of-00002.safetensors:  85% 8.45G/10.0G [06:14<00:32, 46.9MB/s]
#
# model-00001-of-00002.safetensors:  85% 8.52G/10.0G [06:15<00:25, 57.7MB/s]
#
# model-00001-of-00002.safetensors:  86% 8.59G/10.0G [06:16<00:20, 69.8MB/s]
#
# model-00001-of-00002.safetensors:  87% 8.66G/10.0G [06:16<00:15, 84.3MB/s]
#
# model-00001-of-00002.safetensors:  87% 8.72G/10.0G [06:17<00:14, 86.3MB/s]
#
# model-00001-of-00002.safetensors:  88% 8.79G/10.0G [06:17<00:10, 113MB/s]
#
# model-00001-of-00002.safetensors:  89% 8.86G/10.0G [06:18<00:11, 98.2MB/s]
#
# model-00001-of-00002.safetensors:  89% 8.86G/10.0G [06:28<00:11, 98.2MB/s]
#
# model-00001-of-00002.safetensors:  89% 8.92G/10.0G [06:35<01:31, 11.8MB/s]
#
# model-00001-of-00002.safetensors:  90% 8.99G/10.0G [06:36<01:04, 15.6MB/s]
#
# model-00001-of-00002.safetensors:  91% 9.06G/10.0G [06:36<00:42, 22.1MB/s]
#
# model-00001-of-00002.safetensors:  91% 9.12G/10.0G [06:41<00:47, 18.2MB/s]
#
# model-00001-of-00002.safetensors:  92% 9.19G/10.0G [06:42<00:33, 24.3MB/s]
#
# model-00001-of-00002.safetensors:  93% 9.26G/10.0G [06:43<00:23, 31.9MB/s]
#
# model-00001-of-00002.safetensors:  93% 9.33G/10.0G [06:43<00:15, 43.8MB/s]
#
# model-00001-of-00002.safetensors:  94% 9.39G/10.0G [06:44<00:11, 51.2MB/s]
#
# model-00001-of-00002.safetensors:  95% 9.46G/10.0G [06:44<00:08, 64.8MB/s]
#
# model-00001-of-00002.safetensors:  95% 9.53G/10.0G [06:50<00:17, 27.3MB/s]
#
# model-00001-of-00002.safetensors:  96% 9.59G/10.0G [06:50<00:10, 37.4MB/s]
#
# model-00001-of-00002.safetensors:  97% 9.66G/10.0G [06:56<00:14, 22.7MB/s]
#
# model-00001-of-00002.safetensors:  97% 9.73G/10.0G [06:56<00:08, 30.7MB/s]
#
# model-00001-of-00002.safetensors:  98% 9.80G/10.0G [06:57<00:05, 35.7MB/s]
#
# model-00001-of-00002.safetensors:  98% 9.80G/10.0G [07:08<00:05, 35.7MB/s]
#
# model-00001-of-00002.safetensors:  99% 9.86G/10.0G [07:43<00:30, 4.45MB/s]
#
# model-00001-of-00002.safetensors: 100% 10.0G/10.0G [07:44<00:00, 21.5MB/s]
# Fetching 2 files: 100% 2/2 [07:44<00:00, 232.28s/it]
# Loading checkpoint shards: 100% 2/2 [00:42<00:00, 21.14s/it]
# generation_config.json: 100% 141/141 [00:00<00:00, 1.40MB/s]
# processor_config.json: 100% 68.0/68.0 [00:00<00:00, 647kB/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json: 100% 432/432 [00:00<00:00, 4.14MB/s]
# tokenizer_config.json: 100% 882/882 [00:00<00:00, 7.20MB/s]
# vocab.json: 798kB [00:00, 77.2MB/s]
# merges.txt: 456kB [00:00, 114MB/s]
# tokenizer.json: 3.56MB [00:00, 210MB/s]
# added_tokens.json: 100% 23.0/23.0 [00:00<00:00, 244kB/s]
# special_tokens_map.json: 100% 548/548 [00:00<00:00, 5.79MB/s]
# Running forward hooks on data: 100% 2/2 [00:02<00:00,  1.05s/it]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# | 列名             | 内容                | 例                                                 |
# | -------------- | ----------------- | ------------------------------------------------- |
# | `id`           | 実験・記録の通し番号        | 1, 2, 3, ...                                      |
# | `name`         | モデル名              | `Salesforce/blip2-opt-2.7b`                       |
# | `architecture` | モデルの種類            | `blip2`, `llava`, など                              |
# | `timestamp`    | 実行時刻              | `2025-10-18 23:04:24`                             |
# | `image_path`   | 処理対象の画像パス         | `/content/vlm-lens/data/test-images/...`          |
# | `prompt`       | 入力プロンプト           | `"Describe the color in this image in one word."` |
# | `layer`        | どの層のテンソルを取得したか    | `vision_model.post_layernorm`など                   |
# | `tensor_dim`   | ベクトルの次元数          | 1408 や 50304                                      |
# | `tensor`       | 実際の中間表現（埋め込みベクトル） | バイナリ圧縮データ（b'PK\x03...'）                           |

# %%
import sqlite3
import pandas as pd

# データベースファイルのパス
db_path = '/content/vlm-lens/output/blip2-opt-2.7b.db'

# SQLiteデータベースに接続
conn = sqlite3.connect(db_path)

# データベースの全データをDataFrameに読み込む
df = pd.read_sql_query("SELECT * FROM tensors;", conn)

# 接続を閉じる
conn.close()

# データの表示
print("DataFrameの先頭5行:")
print(df.head())
print("\nDataFrameの情報を表示:")
print(df.info())
# Out:
# DataFrameの先頭5行:
#    id                       name architecture            timestamp  \
# 0   1  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:24
# 1   2  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:24
# 2   3  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:24
# 3   4  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:25
# 4   5  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:25
#
#                                           image_path image_id  \
# 0  /content/vlm-lens/data/test-images/black_in_bl...     None
# 1  /content/vlm-lens/data/test-images/black_in_bl...     None
# 2  /content/vlm-lens/data/test-images/black_in_bl...     None
# 3  /content/vlm-lens/data/test-images/black_in_bl...     None
# 4  /content/vlm-lens/data/test-images/black_in_bl...     None
#
#                                           prompt label  \
# 0  Describe the color in this image in one word.  None
# 1  Describe the color in this image in one word.  None
# 2  Describe the color in this image in one word.  None
# 3  Describe the color in this image in one word.  None
# 4  Describe the color in this image in one word.  None
#
#                          layer pooling_method  tensor_dim  \
# 0  vision_model.post_layernorm           None        1408
# 1  vision_model.post_layernorm           None        1408
# 2       language_model.lm_head           None       50304
# 3  vision_model.post_layernorm           None        1408
# 4  vision_model.post_layernorm           None        1408
#
#                                               tensor
# 0  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 1  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 2  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 3  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 4  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
#
# DataFrameの情報を表示:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              6 non-null      int64
#  1   name            6 non-null      object
#  2   architecture    6 non-null      object
#  3   timestamp       6 non-null      object
#  4   image_path      6 non-null      object
#  5   image_id        0 non-null      object
#  6   prompt          6 non-null      object
#  7   label           0 non-null      object
#  8   layer           6 non-null      object
#  9   pooling_method  0 non-null      object
#  10  tensor_dim      6 non-null      int64
#  11  tensor          6 non-null      object
# dtypes: int64(2), object(10)
# memory usage: 708.0+ bytes
# None

# %%
df.head()
# Out:
#    id                       name architecture            timestamp  \
# 0   1  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:24
# 1   2  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:24
# 2   3  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:24
# 3   4  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:25
# 4   5  Salesforce/blip2-opt-2.7b        blip2  2025-10-18 23:04:25
#
#                                           image_path image_id  \
# 0  /content/vlm-lens/data/test-images/black_in_bl...     None
# 1  /content/vlm-lens/data/test-images/black_in_bl...     None
# 2  /content/vlm-lens/data/test-images/black_in_bl...     None
# 3  /content/vlm-lens/data/test-images/black_in_bl...     None
# 4  /content/vlm-lens/data/test-images/black_in_bl...     None
#
#                                           prompt label  \
# 0  Describe the color in this image in one word.  None
# 1  Describe the color in this image in one word.  None
# 2  Describe the color in this image in one word.  None
# 3  Describe the color in this image in one word.  None
# 4  Describe the color in this image in one word.  None
#
#                          layer pooling_method  tensor_dim  \
# 0  vision_model.post_layernorm           None        1408
# 1  vision_model.post_layernorm           None        1408
# 2       language_model.lm_head           None       50304
# 3  vision_model.post_layernorm           None        1408
# 4  vision_model.post_layernorm           None        1408
#
#                                               tensor decoded_tensor
# 0  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...           None
# 1  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...           None
# 2  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...           None
# 3  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...           None
# 4  b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...           None

# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt


# --- tensor列のバイナリをデコード ---
def decode_tensor(blob):
    try:
        # b'PK...' は zip圧縮されている場合が多い
        return pickle.loads(blob)
    except Exception:
        return None

df["decoded_tensor"] = df["tensor"].apply(lambda x: decode_tensor(eval(x)) if isinstance(x, str) else None)

# --- Noneを除外 ---
valid_df = df[df["decoded_tensor"].notnull()]

# --- 1次元配列化 ---
X = np.stack(valid_df["decoded_tensor"].to_numpy())

# --- PCAで2次元に圧縮 ---
pca = PCA(n_components=2)
X_2d = pca.fit_transform(X)

# --- 可視化 ---
plt.figure(figsize=(6,6))
plt.scatter(X_2d[:,0], X_2d[:,1])
plt.title("VLM-LENS Layer Embedding Distribution")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3383640953.py in <cell line: 0>()
#      20
#      21 # --- 1次元配列化 ---
# ---> 22 X = np.stack(valid_df["decoded_tensor"].to_numpy())
#      23
#      24 # --- PCAで2次元に圧縮 ---
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/shape_base.py in stack(arrays, axis, out, dtype, casting)
#     451     arrays = [asanyarray(arr) for arr in arrays]
#     452     if not arrays:
# --> 453         raise ValueError('need at least one array to stack')
#     454
#     455     shapes = {arr.shape for arr in arrays}
#
# ValueError: need at least one array to stack

# %%
df["decoded_tensor"] = df["tensor"].apply(decode_tensor)
df["tensor"]
# Out:
# 0    b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 1    b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 2    b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 3    b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 4    b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# 5    b'PK\x03\x04\x00\x00\x08\x08\x00\x00\x00\x00\x...
# Name: tensor, dtype: object

# %% [markdown]
# 中身のデータは以下通りに並んでいる。
#
# ['archive/data.pkl', 'archive/.format_version', 'archive/.storage_alignment', 'archive/byteorder', 'archive/data/0', 'archive/version', 'archive/.data/serialization_id']

# %%
import io
import torch

def decode_tensor_from_bytes(b):
    try:
        # torch.loadは、zip形式のアーカイブを自動で解釈できる
        tensor = torch.load(io.BytesIO(b), map_location="cpu", weights_only=False)
        return tensor
    except Exception as e:
        print("decode error:", e)
        return None

df["decoded_tensor"] = df["tensor"].apply(decode_tensor_from_bytes)
df["decoded_tensor"]
# Out:
# 0    [[[tensor(0.0092), tensor(-0.9789), tensor(0.5...
# 1    [[tensor(-0.0783), tensor(-2.2005), tensor(0.9...
# 2    [[[tensor(3.0156, dtype=torch.float16), tensor...
# 3    [[[tensor(0.0497), tensor(-0.9158), tensor(0.3...
# 4    [[tensor(0.0133), tensor(-2.0177), tensor(0.68...
# 5    [[[tensor(3.5059, dtype=torch.float16), tensor...
# Name: decoded_tensor, dtype: object

# %%
import matplotlib.pyplot as plt

tensor = df["decoded_tensor"].iloc[0][0]
if tensor is not None:
    plt.plot(tensor.numpy())
    plt.title("Decoded Tensor Values")
    plt.show()

# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# --- Noneを除外 ---
valid_df = df[df["decoded_tensor"].notnull()]

# --- 1次元配列化 ---
X = np.stack(valid_df["decoded_tensor"][3][0].cpu().numpy())

# --- PCAで2次元に圧縮 ---
pca = PCA(n_components=2)
X_2d = pca.fit_transform(X)

# --- 可視化 ---
plt.figure(figsize=(6,6))
plt.scatter(X_2d[:,0], X_2d[:,1])
plt.title("VLM-LENS Layer Embedding Distribution")
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.show()

# %% [markdown]
# https://anishk23733.github.io/vl-interp/#:~:text=We%20show%20that%20targeted%20edits,such%20as%20zero%2Dshot%20segmentation.

# %%
lm_head_np = np.stack(valid_df["decoded_tensor"][3][0].cpu().numpy())
plt.figure(figsize=(12, 8))
plt.imshow(lm_head_np, cmap='viridis', aspect='auto')
plt.colorbar(label='Activation Value')
plt.title('language_model.lm_head Output')
plt.xlabel('Vocabulary Index')
plt.ylabel('Token Position')
# Out:
# Text(0, 0.5, 'Token Position')

# %%
min_val = -5.0 # 例として最小値を-5.0に設定
max_val = 5.0  # 例として最大値を5.0に設定


plt.figure(figsize=(10, 6))
plt.imshow(lm_head_np, cmap='plasma', aspect='auto', vmin=min_val, vmax=max_val)
plt.colorbar(label='Activation Value')
plt.title('vision_model.post_layernorm Output')
plt.xlabel('Feature Dimension')
plt.ylabel('Patch/Token Index')
# Out:
# Text(0, 0.5, 'Patch/Token Index')
